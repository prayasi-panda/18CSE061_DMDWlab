# %% [markdown]
# <a href="https://colab.research.google.com/github/prayasi-panda/18CSE061_DMDWlab/blob/main/18CSE061_dmdwlab3_assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path="https://raw.githubusercontent.com/prayasi-panda/18CSE061_DMDWlab_assign1/main/tmdb_movies_data.csv"

# %%
import pandas as pd
data=pd.read_csv(path)

# %%
data
# Out:
#            id    imdb_id  popularity  ...  release_year    budget_adj   revenue_adj
# 0      135397  tt0369610   32.985763  ...          2015  1.379999e+08  1.392446e+09
# 1       76341  tt1392190   28.419936  ...          2015  1.379999e+08  3.481613e+08
# 2      262500  tt2908446   13.112507  ...          2015  1.012000e+08  2.716190e+08
# 3      140607  tt2488496   11.173104  ...          2015  1.839999e+08  1.902723e+09
# 4      168259  tt2820852    9.335014  ...          2015  1.747999e+08  1.385749e+09
# ...       ...        ...         ...  ...           ...           ...           ...
# 10861      21  tt0060371    0.080598  ...          1966  0.000000e+00  0.000000e+00
# 10862   20379  tt0060472    0.065543  ...          1966  0.000000e+00  0.000000e+00
# 10863   39768  tt0060161    0.065141  ...          1966  0.000000e+00  0.000000e+00
# 10864   21449  tt0061177    0.064317  ...          1966  0.000000e+00  0.000000e+00
# ...

# %%
data.head()
# Out:
#        id    imdb_id  popularity  ...  release_year   budget_adj   revenue_adj
# 0  135397  tt0369610   32.985763  ...          2015  137999939.3  1.392446e+09
# 1   76341  tt1392190   28.419936  ...          2015  137999939.3  3.481613e+08
# 2  262500  tt2908446   13.112507  ...          2015  101199955.5  2.716190e+08
# 3  140607  tt2488496   11.173104  ...          2015  183999919.0  1.902723e+09
# 4  168259  tt2820852    9.335014  ...          2015  174799923.1  1.385749e+09
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#           id    imdb_id  popularity  ...  release_year   budget_adj revenue_adj
# 10861     21  tt0060371    0.080598  ...          1966       0.0000         0.0
# 10862  20379  tt0060472    0.065543  ...          1966       0.0000         0.0
# 10863  39768  tt0060161    0.065141  ...          1966       0.0000         0.0
# 10864  21449  tt0061177    0.064317  ...          1966       0.0000         0.0
# 10865  22293  tt0060666    0.035919  ...          1966  127642.2792         0.0
#
# [5 rows x 21 columns]

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (1992, 21)

# %%
data.head()
# Out:
#        id    imdb_id  popularity  ...  release_year   budget_adj   revenue_adj
# 0  135397  tt0369610   32.985763  ...          2015  137999939.3  1.392446e+09
# 1   76341  tt1392190   28.419936  ...          2015  137999939.3  3.481613e+08
# 2  262500  tt2908446   13.112507  ...          2015  101199955.5  2.716190e+08
# 3  140607  tt2488496   11.173104  ...          2015  183999919.0  1.902723e+09
# 4  168259  tt2820852    9.335014  ...          2015  174799923.1  1.385749e+09
#
# [5 rows x 21 columns]

# %%
plt.scatter(data['id'],data['revenue'],c='red')
plt.xlabel('id')
plt.ylabel('revenue')
plt.show()

# %%
plt.hist(data['popularity'])
plt.show()

# %%
plt.hist(data['budget'])
plt.show()

# %%
plt.hist(data['budget'],color='orange',edgecolor='white',bins=5)
plt.title=("histogram of budget")
plt.xlabel("vote_count")
plt.ylabel("budget")
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')
sns.regplot(x=data['popularity'],y=data['budget'])

# %%
sns.distplot(data['popularity'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data['revenue'],kde=False) #kde=kernel density estimator if we declare it false then that de line got removed

# %%
sns.distplot(data['revenue'],kde=False,bins=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="popularity",data=data)

# %%
sns.boxplot(y=data['revenue'])

# %%
data.hist(figsize=(15,10));

# %%
data.describe()
# Out:
#                   id   popularity  ...    budget_adj   revenue_adj
# count    1992.000000  1992.000000  ...  1.992000e+03  1.992000e+03
# mean    71652.152108     1.316763  ...  3.627376e+07  1.302391e+08
# std     92355.883915     1.873563  ...  5.129783e+07  2.564338e+08
# min        11.000000     0.000620  ...  0.000000e+00  0.000000e+00
# 25%      9699.000000     0.384079  ...  0.000000e+00  0.000000e+00
# 50%     35112.500000     0.774223  ...  1.524601e+07  2.806370e+07
# 75%     83573.000000     1.538639  ...  5.064450e+07  1.393645e+08
# max    414419.000000    32.985763  ...  4.250000e+08  2.827124e+09
#
# [8 rows x 10 columns]

# %%
data.hist(figsize=(12,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f77373b3ef0>,
# ...
#       dtype=object)

# %%
data.hist(figsize=(12,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f77310fcef0>,
# ...
#       dtype=object)

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True )
